# %% [markdown]
# # AMHT Colab Runner
#
# This notebook installs dependencies, checks GPU availability, runs a short 8K training smoke test, and then runs evaluation.

# %%
# !nvidia-smi

# %% [markdown]
# ## Get The Repo
#
# Use one of the options below.
#
# Option A: upload this repo as a zip and unzip it in `/content`.
#
# Option B: clone from your own Git remote.

# %%
# Example clone command:
# !git clone <your-repo-url> /content/amht-codex

# %cd /content/amht-codex

# %%
# !bash scripts/colab_setup.sh

# %%
# !PYTHONUNBUFFERED=1 python train/train.py --config train/config_colab_t4.yaml --seq-len 8192 --steps 3 --device cuda

# %%
# !python eval/benchmark.py --config train/config_colab_t4.yaml --task all --seq-len 8192 --device cuda
